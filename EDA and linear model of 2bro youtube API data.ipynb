# %% [markdown]
# # Introduction
# For several years, I have been a fan of the YouTube channel, 2BRO [(兄者弟者)](https://www.youtube.com/user/norunine). With over 3 million subscribers, the channel consists of three Japanese men hosting gameplays of popular games, particularly FPS and horror games.
#
# Recently, after discovering a method to extract the YouTube API data from the YouTuber/ Data scientist,  [Thu Vu](https://youtu.be/D56_Cx36oGY),  I was intrigued to explore the data related to one of my favourite YouTube channels.
#
# One aspect that particularly caught my attention was the variable like counts and how it related to other variables such as view count.

# %%
# Libraries for handling data 
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Library specific to Kaggle
import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# Library for data visualisation
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline  
import plotly.express as px
# Out:
# /kaggle/input/-2bro-youtube-aip-data/2Bro video data.csv

# %% [markdown]
# # Overview
#
# Using the [method](https://github.com/thu-vu92/youtube-api-analysis) outlined by Thu Vu, a relatively clean dataset can be obtained. For 2BRO, this entails a dataset of just under 8000 videos as of 28th May 2022. The variables include titles and descriptions as well as length of videos and publication date.
#
# Prior to proceeding to understand the interactions between likes and other variables, it may be best to understand the data EDA.
#
# As for the relationships, to ensure that this hypothesis is does not simply examine whether the two variables a correlated the following hypothesis may be evaluated.
#
#     Null hypothesis - There is no linear relationship between (independent variable) and likes (dependent variable).

# %%
# import dataset
df = pd.read_csv("/kaggle/input/-2bro-youtube-aip-data/2Bro video data.csv", index_col = "video_id" )

# %%
# view top 5 rows of dataset 
df.head(5)
# Out:
#             channelTitle                                              title  \
# video_id
# Mnev7ROTbGU         兄者弟者                     【デッドバイデイライト】ロッカーの申し子弟者 #shorts
# uGnIYBuucnc         兄者弟者                    #1【ホラー】弟者の「頭痛（HEADACHE）」【2BRO.】
# vNe26_L47Js         兄者弟者   【BP2倍だってー！？】弟者,おついちの「デッドバイデイライト（DbD）」【2BRO.】#277
# wLvYqjQvaMs         兄者弟者  #47【ナイトランナーに必要なもの】弟者の「ダイイングライト2 ステイ ヒューマン」【2BRO.】
# 70YHp-8Fbxg         兄者弟者            【ホラー】弟者,兄者,おついち,メロ「Occult（オカルト）」【2BRO.】
#
#                                                    description  \
# video_id
# Mnev7ROTbGU  【ゴールデンデドバイ】弟者,おついちの「デッドバイデイライト（DbD）」【2BRO.】#26...
# uGnIYBuucnc  ★最新投稿情報はツイッターで！《@Otojya》https://twitter.com/ot...
# vNe26_L47Js  【デッドバイデイライトの"生放送"再生リスト】https://www.youtube.com...
# wLvYqjQvaMs  公式サイト：https://bit.ly/2broDL2\n\n【ダイイングライト2の再生リ...
# 70YHp-8Fbxg  ★最新投稿情報はツイッターで！《@Otojya》https://twitter.com/ot...
#
#                                                           tags  \
# video_id
# Mnev7ROTbGU  ['2BRO.', 'ホラー', '弟者', 'Dead by Daylight', 'デッ...
# uGnIYBuucnc  ['2BRO.', 'ホラー', '弟者', 'ゲーム実況', '実況', 'アクション',...
# vNe26_L47Js  ['2BRO.', 'ホラー', '弟者', 'Dead by Daylight', 'デッ...
# wLvYqjQvaMs  ['ゲーム実況', '実況', '弟者', '2BRO', 'FPS', 'アクションホラー...
# 70YHp-8Fbxg                                                NaN
#
#                            publishedAt  viewCount  likeCount  favouriteCount  \
# video_id
# Mnev7ROTbGU  2022-05-28 13:00:21+00:00    82177.0     2521.0             NaN
# uGnIYBuucnc  2022-05-28 11:00:32+00:00   154606.0     2761.0             NaN
# vNe26_L47Js  2022-05-28 09:14:23+00:00   150003.0     2251.0             NaN
# wLvYqjQvaMs  2022-05-28 09:00:22+00:00    23417.0      616.0             NaN
# 70YHp-8Fbxg  2022-05-27 14:17:28+00:00   440643.0     6388.0             NaN
#
#              commentCount    duration definition  caption pushblishDayName  \
# video_id
# Mnev7ROTbGU          35.0       PT10S         hd    False         Saturday
# uGnIYBuucnc         102.0    PT26M55S         hd    False         Saturday
# vNe26_L47Js          14.0   PT4H9M36S         hd    False         Saturday
# wLvYqjQvaMs          50.0     PT29M8S         hd    False         Saturday
# 70YHp-8Fbxg         134.0  PT1H43M59S         hd    False           Friday
#
#              durationSecs  tagCount
# video_id
# Mnev7ROTbGU          10.0        12
# uGnIYBuucnc        1615.0        10
# vNe26_L47Js       14976.0        12
# wLvYqjQvaMs        1748.0        15
# 70YHp-8Fbxg        6239.0         0

# %%
# check basic stats for the data including data type and null values
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7998 entries, Mnev7ROTbGU to GQPXCXLLbt0
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   channelTitle      7998 non-null   object
#  1   title             7998 non-null   object
#  2   description       7998 non-null   object
#  3   tags              7906 non-null   object
#  4   publishedAt       7998 non-null   object
#  5   viewCount         7998 non-null   float64
#  6   likeCount         7998 non-null   float64
#  7   favouriteCount    0 non-null      float64
#  8   commentCount      7998 non-null   float64
#  9   duration          7998 non-null   object
#  10  definition        7998 non-null   object
#  11  caption           7998 non-null   bool
#  12  pushblishDayName  7998 non-null   object
#  13  durationSecs      7998 non-null   float64
#  14  tagCount          7998 non-null   int64
# dtypes: bool(1), float64(5), int64(1), object(8)
# memory usage: 945.1+ KB

# %% [markdown]
# # EDA
# ## Amending variables
# As there are no values in favourite counts, this column can be dropped. In addition, as Thu Vu's method included coding to convert the duration listed in PT to seconds, the original duration can be likewise dropped.

# %%
# drop favourite counts and duration columns 
df.drop(["favouriteCount","duration" ], axis = 1, inplace = True)

# %% [markdown]
# Furthermore, the publication variable includes both dates and time. As such it may be best to separate the the data into two variables, with the date being appropriately formatted.

# %%
# seperate published at variable which includes date and time to two variables
df[["Publish_date", "Publish_time"]] = df["publishedAt"].str.split(" ", expand = True)

# %%
# reformat date variable to datetime 
df["Publish_date"] = pd.to_datetime(df["Publish_date"], format = "%Y-%m-%d")

# %%
# drop published at variable
df.drop(["publishedAt" ], axis = 1, inplace = True)

# %% [markdown]
# ## Duration
# There are a myriad of places to begin examining the variables. However, one aspect that is of particular intriguing as a subscriber to the channel is the duration of the videos.
#
# 2BRO frequently host extremely long videos and as a general observer it is unclear if these are outliers. In addition, YouTube has recently introduced shorts and these operate differently from typical videos.

# %%
# view distribution of durationSecs variable
fig = px.histogram(df, x ="durationSecs",)
fig.update_layout(title_text="Length of videos", title_x=0.5)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.12.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# <div>                            <div id="101ee871-eb5a-44fc-819a-050cb3fd040f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById
1334.0,18.0,8447.0,902.0,7716.0,15631.0,49.0,1022.0,11148.0,12927.0,60.0,1997.0,13465.0,2003.0,51.0,5571.0,2504.0,1946.0,13793.0,15161.0,13.0,11630.0,934.0,8281.0,13919.0,16.0,903.0,5739.0,14.0,8965.0,842.0,23795.0,776.0,19.0,12401.0,810.0,11759.0,12337.0,2195.0,1598.0,6.0,6987.0,2119.0,1954.0,17.0,552.0,8247.0,10.0,767.0,5362.0,14.0,4342.0,805.0,12581.0,8788.0,18.0,1114.0,6917.0,19.0,1312.0,9997.0,14533.0,3574.0,1132.0,3505.0,15.0,2160.0,1146.0,7635.0,17.0,21045.0,16.0,811.0,6317.0,17.0,9943.0,18.0,663.0,12099.0,1131.0,5043.0,16781.0,1689.0,7065.0,10485.0,1077.0,2156.0,3221.0,1583.0,612.0,2437.0,1318.0,12569.0,2307.0,10465.0,1914.0,11641.0,1462.0,10871.0,9865.0,1538.0,7737.0,6129.0,1929.0,9101.0,2266.0,836.0,683.0,11957.0,3552.0,2402.0,1019.0,5539.0,1929.0,5062.0,1267.0,16401.0,7953.0,1250.0,13901.0,1222.0,1461.0,5705.0,28823.0,1120.0,1575.0,809.0,8189.0,2356.0,1007.0,445.0,9735.0,1001.0,9980.0,12667.0,1588.0,4885.0,1639.0,7555.0,7909.0,1120.0,1121.0,4101.0,12910.0,11857.0,1152.0,10055.0,11484.0,810.0,796.0,11894.0,989.0,905.0,10708.0,1039.0,21589.0,11003.0,1004.0,14105.0,1057.0,11173.0,15026.0,829.0,10533.0,1356.0,14505.0,626.0,11082.0,1296.0,6921.0,8154.0,1177.0,13200.0,21896.0,1 ...

# %% [markdown]
# ### Shorts
# Recently YouTube has introduced shorts, which are clips that are [60 seconds or under](https://support.google.com/youtube/answer/10059070?hl=en-GB#:~:text=YouTube%20Shorts%20is%20a%20way,with%20our%20multi%2Dsegment%20camera). These clips operate in a different manner to typical videos. Therefore the dataset can be divided into those which are above and below 60 seconds. For 2BRO, there is 116 shorts and 7881 videos.

# %%
# seperate clips to those that are less than 60secs (shorts) and longer than 60secs (videos)
shorts = df[df["durationSecs"]<60]
videos = df[df["durationSecs"]>60]

# %%
# print the number of clips in both datasets 
print( "There are", shorts.shape[0], "shorts and", videos.shape[0], "videos")
# Out:
# There are 116 shorts and 7881 videos

# %% [markdown]
# ### Video
# Examining the videos further, the average video is 47mins long. However it appears that there are extremely long videos. The maximum runtime for one video is approx. 8 hours.

# %%
# view distribution of durationSecs variable for videos
sns.displot(x = "durationSecs", data = videos,height =6)
plt.title("Length of videos")

plt.show()

# %%
# descriptive statistics for durationSecs on videos 
videos["durationSecs"].describe()
# Out:
# count     7881.000000
# mean      2815.524553
# std       2777.801543
# min         61.000000
# 25%       1386.000000
# 50%       1952.000000
# 75%       2882.000000
# max      28823.000000
# Name: durationSecs, dtype: float64

# %%
# print key stats for durationSecs on videos 
print("Average videos are", round(videos["durationSecs"].mean()/60,0), "mins long, with the longest video approx.", round((videos["durationSecs"].max()/60)/60,0), "hours long.")
# Out:
# Average videos are 47.0 mins long, with the longest video approx. 8.0 hours long.

# %%
# Data on the longest video
videos[videos["durationSecs"]==videos["durationSecs"].max()]
# Out:
#             channelTitle                                  title  \
# video_id
# zAS4UTzo8vE         兄者弟者  #219【ほろ酔い】弟者の「デッドバイデイライト（DbD）」【2BRO.】
#
#                                                    description  \
# video_id
# zAS4UTzo8vE  【デッドバイデイライトの"生放送"再生リスト】https://www.youtube.com...
#
#                                                           tags  viewCount  \
# video_id
# zAS4UTzo8vE  ['2BRO.', 'ホラー', '弟者', 'Dead by Daylight', 'デッ...   481357.0
#
#              likeCount  commentCount definition  caption pushblishDayName  \
# video_id
# zAS4UTzo8vE     4794.0         166.0         hd    False           Monday
#
#              durationSecs  tagCount Publish_date    Publish_time
# video_id
# zAS4UTzo8vE       28823.0        12   2022-01-24  20:55:45+00:00

# %% [markdown]
# ### Radio
# In addition to games, 2BRO also has a monthly wrap up in the form of a radio show. This series currently have 154 episodes, based on the title of the most recent episode.
#
# However, after extracting the data, it appears that the numerical values do not include special episodes. Including such episodes, there are 157 episodes in total.

# %%
# extract videos with the phrase 2broRadio in the title
radio = videos[videos['title'].str.contains("2broRadio")]

# examine overview of the videos with 2broRadio in the title
radio.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 157 entries, idJFQ40y9O4 to KdzPR60Z_E4
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   channelTitle      157 non-null    object
#  1   title             157 non-null    object
#  2   description       157 non-null    object
#  3   tags              151 non-null    object
#  4   viewCount         157 non-null    float64
#  5   likeCount         157 non-null    float64
#  6   commentCount      157 non-null    float64
#  7   definition        157 non-null    object
#  8   caption           157 non-null    bool
#  9   pushblishDayName  157 non-null    object
#  10  durationSecs      157 non-null    float64
#  11  tagCount          157 non-null    int64
#  12  Publish_date      157 non-null    datetime64[ns]
#  13  Publish_time      157 non-null    object
# dtypes: bool(1), datetime64[ns](1), float64(4), int64(1), object(7)
# memory usage: 17.3+ KB

# %%
# check unqiue values in the title variable
radio["title"].unique()
# Out:
# array(['2broRadio【vol.154】', '2broRadio【vol.153】※一部音声不具合あり',
#        '2broRadio【vol.152】', '2broRadio【vol.151】', '2broRadio【vol.150】',
#        '2broRadio【vol.149】', '2broRadio【vol.148】', '2broRadio【vol.147】',
#        '2broRadio【vol.146】', '2broRadio【vol.145】', '2broRadio【vol.144】',
#        '2broRadio【vol.143】', '2broRadio【vol.142】', '2broRadio【vol.141】',
#        '2broRadio【vol.140】', '2broRadio【vol.139】',
#        '2broRadio【vol.138】2021年初ラジオ', '2broRadio【vol.137】2020年ラスト',
#        '2broRadio【vol.136】', '2broRadio【vol.135】', '2broRadio【vol.134】',
#        '2broRadio【vol.133】', '2broRadio【vol.132】', '2broRadio【vol.131】',
#        '【サイバーパンク2077最新情報】2broRadio【特別番組】', '2broRadio【vol.130】',
#        '2broRadio【vol.129】with 大塚明夫さん', '2broRadio【vol.128】',
#        '2broRadio【vol.127】', '2broRadio【vol.126】', '2broRadio【vol.125】',
#        '2broRadio【vol.124】', '2broRadio【vol.123】', '2broRadio【vol.122】',
#        '2broRadio【vol.19】', '2broRadio【vol.18】', '2broRadio【vol.17】',
#        '2broRadio【vol.16】', '2broRadio【vol.15】',
#        '2broRadio 【vol.14】夏のホラー２時間スペシャル', '2broRadio【vol.13】',
#        '2broRadio【vol.12】', '2broRadio【vol.11】', '2broRadio【vol.10】',
#        '2broRadio【vol.9】', '2broRadio【vol.8】at E3', '2broRadio【vol.7】',
#        '2broRadio【vol.6】', '2broRadio【vol.5】', '2broRadio【vol.4】',
#        '2broRadio【vol.3】', '2broRadio【vol.2】', '2broRadio【vol.1】'],
#       dtype=object)

# %% [markdown]
# Interestingly a few radio episodes do not have tags.

# %%
# videos with no tags
radio[radio["tags"].isnull()]
# Out:
#             channelTitle                          title  \
# video_id
# i-0HWU2l-aY         兄者弟者             2broRadio【vol.136】
# YUUtEVvexKQ         兄者弟者             2broRadio【vol.130】
# 6jV6ArADEvU         兄者弟者  2broRadio【vol.129】with 大塚明夫さん
# sGALeuTJyzc         兄者弟者             2broRadio【vol.128】
# IUcVkh9yd1k         兄者弟者             2broRadio【vol.127】
# 1W3pU2vYJIE         兄者弟者             2broRadio【vol.126】
#
#                                                    description tags  \
# video_id
# i-0HWU2l-aY  【2broRadioの再生リスト】https://www.youtube.com/playl...  NaN
# YUUtEVvexKQ  【2broRadioの再生リスト】https://www.youtube.com/playl...  NaN
# 6jV6ArADEvU  【2broRadioの再生リスト】https://www.youtube.com/playl...  NaN
# sGALeuTJyzc  【2broRadioの再生リスト】https://www.youtube.com/playl...  NaN
# IUcVkh9yd1k  【2broRadioの再生リスト】https://www.youtube.com/playl...  NaN
# 1W3pU2vYJIE  【2broRadioの再生リスト】https://www.youtube.com/playl...  NaN
#
#              viewCount  likeCount  commentCount definition  caption  \
# video_id
# i-0HWU2l-aY   331532.0     4446.0          98.0         hd    False
# YUUtEVvexKQ   707175.0     6539.0         222.0         hd    False
# 6jV6ArADEvU  1585094.0    52685.0        1959.0         hd    False
# sGALeuTJyzc   343383.0     4420.0         161.0         hd    False
# IUcVkh9yd1k   399507.0     5216.0         169.0         hd    False
# 1W3pU2vYJIE   352177.0     4756.0         136.0         hd    False
#
#             pushblishDayName  durationSecs  tagCount Publish_date  \
# video_id
# i-0HWU2l-aY        Wednesday        6531.0         0   2020-12-02
# YUUtEVvexKQ           Monday       10341.0         0   2020-05-18
# 6jV6ArADEvU           Monday        4711.0         0   2020-04-20
# sGALeuTJyzc           Monday        6403.0         0   2020-03-23
# IUcVkh9yd1k           Monday        5845.0         0   2020-02-24
# 1W3pU2vYJIE           Monday        4039.0         0   2020-01-27
#
#                Publish_time
# video_id
# i-0HWU2l-aY  11:53:36+00:00
# YUUtEVvexKQ  13:51:36+00:00
# 6jV6ArADEvU  11:31:49+00:00
# sGALeuTJyzc  12:26:08+00:00
# IUcVkh9yd1k  11:45:15+00:00
# 1W3pU2vYJIE  12:20:41+00:00

# %% [markdown]
# Although the channel does have other one off special episodes such as holiday specials and reports from gaming shows, as radio shows are a common feature, this is the only series that is excluded. This includes biannual wrap ups. To remove the other types of videos, in-depth review of the title or tag columns will be needed.

# %%
# extract videos with no 2broRadio in the title
games = videos[~videos['title'].str.contains("2broRadio")]
games.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7724 entries, uGnIYBuucnc to GQPXCXLLbt0
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   channelTitle      7724 non-null   object
#  1   title             7724 non-null   object
#  2   description       7724 non-null   object
#  3   tags              7647 non-null   object
#  4   viewCount         7724 non-null   float64
#  5   likeCount         7724 non-null   float64
#  6   commentCount      7724 non-null   float64
#  7   definition        7724 non-null   object
#  8   caption           7724 non-null   bool
#  9   pushblishDayName  7724 non-null   object
#  10  durationSecs      7724 non-null   float64
#  11  tagCount          7724 non-null   int64
#  12  Publish_date      7724 non-null   datetime64[ns]
#  13  Publish_time      7724 non-null   object
# dtypes: bool(1), datetime64[ns](1), float64(4), int64(1), object(7)
# memory usage: 852.4+ KB

# %% [markdown]
# ## Publication Day Name
# The majority of channels release videos in a consistent manner. For 2BRO, this entails uploading one or more videos everyday. That being said, Monday, Tuesday and Thursday are days were the channel is most likely to not upload less.

# %%
# visualisation upload schedule
plt.figure(figsize = (20,8))
sns.countplot(x ="pushblishDayName", data = games, order=['Monday','Tuesday','Wednesday','Thursday','Friday','Saturday','Sunday'], palette = "mako")
plt.title("Upload scheduel by the days of the week")

plt.show()

# %% [markdown]
# As these string variables cannot be used in the modelling process as is, they are  encoded to a numerical value.

# %%
# import library for encoding 
from sklearn.preprocessing import LabelEncoder

# %%
# as operations will be conducted on slices or the orginal data, below code has been added to stop an error warning. 
pd.options.mode.chained_assignment = None

# create a new variable encording the publis day name
le = LabelEncoder()
games["pushblishDayName_code"] = le.fit_transform(games["pushblishDayName"])

# %% [markdown]
# ## Tags
# As indicated previously, there are videos which do not have any tags. Investigating the data further, number of tags range from 0 to 26 and the average is around 11. The most common number of tags is slightly higher at approx. 12 tags.

# %%
# visualisation of number of tags
plt.figure(figsize = (20,8))
sns.countplot(x ="tagCount", data = games, palette = "Blues")
plt.title("No. of tags per video")
plt.show()

# %%
# descriptive statistics on the tag count variable
games["tagCount"].describe()
# Out:
# count    7724.000000
# mean       10.748446
# std         2.762942
# min         0.000000
# 25%         9.000000
# 50%        11.000000
# 75%        13.000000
# max        26.000000
# Name: tagCount, dtype: float64

# %% [markdown]
# Highlighted by the boxplot, there are outliers in the number of tags. Subsequently, using the IQR, they are excluded. There are still low tag counts but the extremely low and high values have been removed.

# %%
# distribution of tag counts and outliers
plt.figure(figsize = (20,8))
sns.boxplot(x ="tagCount", data = games, palette = "Blues")
plt.title("Distribution of the Tag counts")
plt.show()

# %%
# remove outliers via IQR
# locate q25 and q75
q25 = games["tagCount"].quantile(0.25)
q75 = games["tagCount"].quantile(0.75)

# identify the range
iqr = q75-q25

# secur the upper and lower limit
upper_limit = q75 + 1.5*iqr
lower_limit = q25-1.5*iqr

# excluude variables that fall above or below the limits
games_tag = games[(games["tagCount"]<= upper_limit) &(games["tagCount"]>= lower_limit)]

# %%
# view revised descriptive statistics
games_tag["tagCount"].describe()
# Out:
# count    7621.000000
# mean       10.831387
# std         2.485769
# min         3.000000
# 25%         9.000000
# 50%        11.000000
# 75%        13.000000
# max        19.000000
# Name: tagCount, dtype: float64

# %%
# examine revised dataset and the distribution of tag count
fig = px.histogram(games_tag, x ="tagCount", )

fig.update_layout(title_text = "Distribution of Tags excluding outliers", title_x = .5,)
# Out:
# <div>                            <div id="9950c104-3041-4153-a45d-d3dda426dac0" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("
,13,13,13,7,14,13,14,7,14,8,8,11,14,9,9,14,13,9,7,14,14,13,14,9,7,14,8,8,14,13,13,12,7,11,11,7,14,13,7,9,14,7,7,8,6,8,7,13,13,13,7,11,7,11,7,12,7,12,8,8,11,10,14,12,13,12,7,13,12,13,13,13,7,10,6,13,13,8,8,12,12,13,7,10,8,6,13,12,6,13,7,8,12,13,8,13,14,12,13,13,13,7,13,6,13,12,7,13,13,6,13,12,13,9,11,9,13,12,12,6,12,6,12,13,10,13,12,10,12,12,8,13,12,9,13,9,11,13,13,10,12,12,8,8,8,13,10,8,13,8,13,12,8,12,9,8,12,12,12,11,9,12,15,10,12,12,12,13,10,6,12,15,12,9,12,9,11,15,12,12,12,12,12,12,13,15,13,13,15,11,16,11,12,16,13,12,15,16,12,15,16,13,15,16,12,17,14,13,12,13,12,11,15,11,13,15,15,13,13,15,15,12,15,13,15,12,8,13,8,12,12,13,17,8,13,8,15,13,17,8,8,12,13,15,13,8,12,15,13,12,12,17,13,12,15,13,12,12,13,9,12,13,14,13,9,12,12,14,12,15,14,13,13,14,13,12,12,14,13,10,12,14,11,12,14,12,12,10,13,14,13,13,13,13,13,11,13,11,11,12,8,11,12,8,12,13,8,9,13,13,11,8,13,17,8,17,12,17,12,11,13,12,12,11,12,11,12,13,13,13,12,13,12,13,12,13,12,12,11,12,12,12,12,11,13,12,13,13,13,12,13,13,13,13,12,12,12,12,10,13,12,10,9,13,12,13,13,13,12,12,7,17,12,12,14,11,17,13,14,7,12,14,12,14,7,14,14,12,14,8,12,12,14,13,13,13,14,7,12,13,13,13,7,12,10,10,10,13,13,13,14,7,12,12,12,12,8,7,8,12,10,8,10,12,13,8,8,7,8,8,12,14,7,12,8,10,10,12,8,12,14,7,13,14,12,14,7,14,12,16,10,12,13,10,14,13,10,10,13,13,12,7,7,12,14,12,13,12,12,10,12,10,12,10,12,11,13,12,12,11,12,12,12,10,12,10,13,10,12,12,13,11,12,12,12,13,12,11,13,12,12,13,10,12,10,13,11,12,7,13,13,13,11,12,13,11,12,12,12,13,10,7,12,10,13,8,12,11,13,12,13,11,13,12,12,13,12,13,11,13,13,13,11,11,12,13,10,12,10,12,12,13,13,9,12,13,12,1 ...

# %% [markdown]
# ## Definition
#
# Since the creation of the channel in 2010, the technology around videos have transformed significantly. According to this dataset, the majority of the videos are now in HD. However, there are 72 videos that are in standard definition (SD). These may be dropped as they are now outliers within a dataset where the majority are in HD.

# %%
# Number of HD and SD definition videos
plt.figure(figsize = (10,8))

sns.countplot(x ="definition" , data =games_tag, palette = "Blues_r")
plt.title("No. of HD and SD definition videos")
plt.show()

# %%
# extract the year from datetime variable of SD videos

sd = games_tag[games_tag["definition"]=="sd"]
sd["year"] =  sd['Publish_date'].dt.year


# Visualisation of year of publication of SD videos
plt.figure(figsize = (10,8))
sns.countplot(x= "year", data =sd, palette = "Blues")
plt.title("Publication year of SD videos")
plt.show()

# %%
# The SD video published in 2018
sd[sd["year"]==2018]
# Out:
#             channelTitle                              title  \
# video_id
# 6du-HNEdxy4         兄者弟者  #4【FPS】弟者の「S.T.A.L.K.E.R.」【2BRO.】
#
#                                                    description  \
# video_id
# 6du-HNEdxy4  【S.T.A.L.K.E.R.の再生リスト】https://www.youtube.com/...
#
#                                                           tags  viewCount  \
# video_id
# 6du-HNEdxy4  ['2BRO.', 'ゲーム実況', '弟者', 'おとじゃ', 'Steam', 'S.T...   293514.0
#
#              likeCount  commentCount definition  caption pushblishDayName  \
# video_id
# 6du-HNEdxy4     1900.0         114.0         sd    False        Wednesday
#
#              durationSecs  tagCount Publish_date    Publish_time  \
# video_id
# 6du-HNEdxy4        2159.0         9   2018-07-04  09:00:00+00:00
#
#              pushblishDayName_code  year
# video_id
# 6du-HNEdxy4                      6  2018

# %%
# exclude SD videos/ keep only HD videos
games_tag_hd = games_tag[games_tag["definition"]=="hd"]

# %% [markdown]
# ## Publication date
# Following some of the changes, the majority of the videos are now from 2013. However, there are still videos from 2010 in this dataset. As the number of videos between 2010 and 2013 are limited, it may be best to cap the data to post 2013.

# %%
# seperate publish date vaiable to month and date
games_tag_hd["year"] =  games_tag_hd['Publish_date'].dt.year
games_tag_hd["month"] =  games_tag_hd['Publish_date'].dt.month

# %%
# distribution of videos though the years
plt.figure(figsize = (20,8))
sns.countplot(x= "year", data =games_tag_hd, palette = "Blues")
plt.title("Year of publication of videos")
plt.show()

# %%
# select videos published after 2013
game_post2013 = games_tag_hd[games_tag_hd["year"]>2013]

# %% [markdown]
# ## Captions
# The majority of the videos do not have a caption - only 295 videos appear to do so. However, reviewing the data of those with captions, it is unclear why they do so. To avoid any unintended distortions, the dataset may be left as is and include those with and without captions.
#
# That being said as this is a binary field that could be used later understanding relationships between variables, it is swapped for a dummy variable.

# %%
# Visualisation of videos with and without captions.

plt.figure(figsize = (20,8))
sns.countplot(x= "caption", data =game_post2013, palette = "Blues")
plt.title("Use of captions in videos")
plt.show()

# %%
# Number of videos with captions 
print("There are", sum(game_post2013["caption"]==True), "videos with captions")
# Out:
# There are 295 videos with captions

# %%
# extrac of videos with captions
game_post2013[game_post2013["caption"]==True].head()
# Out:
#             channelTitle                                           title  \
# video_id
# GwMZT7DIj-U         兄者弟者        #1【FPS】弟者の「The Spy Who Shrunk Me」【2BRO.】
# tm8Ws8McYWU         兄者弟者            #5【アクション】弟者の「Pikuniku（ピクニック）」【2BRO.】
# FWhmTidRxaw         兄者弟者               【まとめ】2BRO.の「2018年上半期動画総集編」【2BRO.】
# oLadv27Csso         兄者弟者  #43【ホラー】弟者,おついちの「デッドバイデイライト シーズン4（DBD）」【2BRO.】
# orYrSEBvjX0         兄者弟者  #42【ホラー】弟者,おついちの「デッドバイデイライト シーズン4（DBD）」【2BRO.】
#
#                                                    description  \
# video_id
# GwMZT7DIj-U  【The Spy Who Shrunk Meの再生リスト】https://www.youtu...
# tm8Ws8McYWU  【Pikuniku（ピクニック）の再生リスト】https://www.youtube.com...
# FWhmTidRxaw  【総集編の再生リスト】https://www.youtube.com/playlist?li...
# oLadv27Csso  【シーズン4】https://www.youtube.com/playlist?list=P...
# orYrSEBvjX0  【シーズン4】https://www.youtube.com/playlist?list=P...
#
#                                                           tags  viewCount  \
# video_id
# GwMZT7DIj-U  ['2BRO.', '弟者', 'ゲーム実況', 'FPS', 'Steam', 'The ...   365066.0
# tm8Ws8McYWU  ['2BRO.', '弟者', 'ゲーム実況', 'Steam', 'Pikuniku', ...   288042.0
# FWhmTidRxaw  ['ゲーム実況', '2BRO.', '総集編', '弟者', '兄者', 'おついち', ...  3096290.0
# oLadv27Csso  ['2BRO.', 'ホラー', '弟者', 'Dead by Daylight', '殺人...   678227.0
# orYrSEBvjX0  ['2BRO.', 'ホラー', '弟者', 'Dead by Daylight', '殺人...   643429.0
#
#              likeCount  commentCount definition  caption pushblishDayName  \
# video_id
# GwMZT7DIj-U     3587.0         225.0         hd     True           Monday
# tm8Ws8McYWU     3187.0         243.0         hd     True           Monday
# FWhmTidRxaw    37033.0        2663.0         hd     True         Saturday
# oLadv27Csso     5851.0         304.0         hd     True        Wednesday
# orYrSEBvjX0     5504.0         324.0         hd     True          Tuesday
#
#              durationSecs  tagCount Publish_date    Publish_time  \
# video_id
# GwMZT7DIj-U        1085.0         7   2019-07-15  11:00:01+00:00
# tm8Ws8McYWU        1416.0         7   2019-04-01  11:00:06+00:00
# FWhmTidRxaw         837.0         8   2018-06-30  13:00:03+00:00
# oLadv27Csso         763.0        12   2018-06-27  12:00:11+00:00
# orYrSEBvjX0         757.0        12   2018-06-26  12:00:04+00:00
#
#              pushblishDayName_code  year  month
# video_id
# GwMZT7DIj-U                      1  2019      7
# tm8Ws8McYWU                      1  2019      4
# FWhmTidRxaw                      2  2018      6
# oLadv27Csso                      6  2018      6
# orYrSEBvjX0                      5  2018      6

# %%
# convert captions to dummy variables
game_post2013["caption_dummy"] = pd.get_dummies(game_post2013["caption"], drop_first = True)
game_post2013.drop("caption", axis= 1, inplace = True)

# %%
# review details on the current dataset
game_post2013.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7428 entries, uGnIYBuucnc to QW59mIVOzTs
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   channelTitle           7428 non-null   object
#  1   title                  7428 non-null   object
#  2   description            7428 non-null   object
#  3   tags                   7428 non-null   object
#  4   viewCount              7428 non-null   float64
#  5   likeCount              7428 non-null   float64
#  6   commentCount           7428 non-null   float64
#  7   definition             7428 non-null   object
#  8   pushblishDayName       7428 non-null   object
#  9   durationSecs           7428 non-null   float64
#  10  tagCount               7428 non-null   int64
#  11  Publish_date           7428 non-null   datetime64[ns]
#  12  Publish_time           7428 non-null   object
#  13  pushblishDayName_code  7428 non-null   int64
#  14  year                   7428 non-null   int64
#  15  month                  7428 non-null   int64
#  16  caption_dummy          7428 non-null   uint8
# dtypes: datetime64[ns](1), float64(4), int64(4), object(7), uint8(1)
# memory usage: 1.2+ MB

# %% [markdown]
# ## Likes
# The likes has a right skew. Therefore, the majority of the videos have under 10, 000 likes but there are some highly viral videos. These extremely high values should be excluded to prevent any unexpected issues when modelling as they are likely to be outliers.

# %%
# distribution of likes
fig = px.violin(game_post2013, x = "likeCount" )

fig.update_layout(title_text = "Distribution of likes in the videos", title_x = .5)
# Out:
# <div>                            <div id="27cc3b22-12a2-4f57-a2f2-068856972c10" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById
.0,152732.0,330876.0,296449.0,213905.0,355217.0,355359.0,193329.0,79333.0,364033.0,127571.0,123820.0,290354.0,114569.0,283893.0,335909.0,113397.0,384578.0,112470.0,214265.0,737386.0,236654.0,194737.0,486542.0,208442.0,88965.0,104277.0,138713.0,188140.0,151001.0,255401.0,304058.0,120110.0,168329.0,256182.0,122519.0,298060.0,462952.0,305656.0,673419.0,317693.0,120283.0,198306.0,145670.0,234315.0,205807.0,139260.0,311265.0,407260.0,162024.0,152864.0,338357.0,108737.0,247969.0,228842.0,296917.0,109925.0,360104.0,162288.0,223575.0,137975.0,313139.0,196184.0,251797.0,418745.0,126914.0,298419.0,228487.0,82261.0,297707.0,10562 ...

# %%
# similar to likes, remove outliers via the IQR
q25 = game_post2013["viewCount"].quantile(0.25)
q75 = game_post2013["viewCount"].quantile(0.75)

iqr = q75-q25


upper_limit = q75 + 1.5*iqr

game_post2013 = game_post2013[(game_post2013["viewCount"]<= upper_limit)]

# %%
# distribution of views
fig = px.violin(game_post2013, x = "commentCount" )
fig. update_layout(title_text = "Comments per video", title_x = .5,)
# Out:
# <div>                            <div id="00f95a69-01fd-4c20-822d-515750f8105b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("00f95a69-01fd-4c20-822d-515750f8105b")) {                    Plotly.newPlot(                        "00f95a69-01fd-4c20-822d-515750f8105b",                        [{"alignmentgroup":"True","box":{"visible":false},"hovertemplate":"commentCount=%{x}<extra></extra>","legendgroup":"","marker":{"color":"#636efa"},"name":"","offsetgroup":"","orientation":"h","scalegroup":"True","showlegend":false,"x":[102.0,14.0,50.0,21.0,18.0,12.0,15.0,28.0,20.0,16.0,164.0,73.0,154.0,17.0,69.0,14.0,75.0,23.0,137.0,47.0,8.0,95.0,95.0,15.0,36.0,15.0,271.0,34.0,23.0,185.0,50.0,20.0,74.0,21.0,16.0,13.0,86.0,20.0,11.0,14.0,34.0,60.0,36.0,47.0,28.0,49.0,24.0,37.0,13.0,44.0,29.0,14.0,14.0,38.0,26.0,29.0,39.0,41.0,52.0,16.0,23.0,14.0,25.0,17.0,18.0,110.0,73.0,30.0,158.0,39.0,25.0,21.0,53.0,19.0,15.0,28.0,13.0,25.0,12.0,35.0,61.0,115.0,38.0,36.0,23.0,30.0,68.0,56.0,61.0,29.0,15.0,16.0,26.0,44.0,14.0,191.0,19.0,15.0,205.0,47.0,55.0,40.0,40.0,25.0,24.0,59.0,60.0,34.0,23.0,16.0,28.0,17.0,136.0,16.0,38.0,53.0,46.0,39.0,41.0,66.0,18.0,131.0,33.0,13.0,22.0,53.0,62.0,11.0,24.0,109.0,78.0,157.0,328.0,45.0,37.0,13.0,31.0,18.0,20.0,40.0,14.0,75.0,77.0,45.0,96.0,78.0,59.0,106.0,33.0,34.0,18.0,42.0,20.0,15.0,58.0,90.0,112.0,46.0,25.0,33.0,32.0,121.0,64.0,23.0,19.0,18.0,144.0,75.0,23.0,92.0,81.0,110.0,23.0,72.0,31.0,48.0,68.0,31.0,35.0,103.0,65.0,36.0,21.0,131.0,22.0,90.0,88.0,18.0,42.0,76.0,97.0,63.0,85.0,35.0,130.0
# %%
# similar to likes, remove outliers via the IQR
q25 = game_post2013["commentCount"].quantile(0.25)
q75 = game_post2013["commentCount"].quantile(0.75)

iqr = q75-q25


upper_limit = q75 + 1.5*iqr

game_post2013 = game_post2013[(game_post2013["commentCount"]<= upper_limit)]

# %% [markdown]
# After these changes, the dataset now has just under 6500 entries. 2BRO is a highly active channel which uploads videos nearly everyday and clips are generally over 30mins long. They also favour around 10 tags per video. They secure on approx. 2500 likes and 150 comments on an average video 360,000 views.

# %%
# copy the revised dataset and reset index 
data_preprocessed = game_post2013.copy()
data_preprocessed = data_preprocessed.reset_index(drop = True)

# %%
# information on the revised dataset
data_preprocessed.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6369 entries, 0 to 6368
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   channelTitle           6369 non-null   object
#  1   title                  6369 non-null   object
#  2   description            6369 non-null   object
#  3   tags                   6369 non-null   object
#  4   viewCount              6369 non-null   float64
#  5   likeCount              6369 non-null   float64
#  6   commentCount           6369 non-null   float64
#  7   definition             6369 non-null   object
#  8   pushblishDayName       6369 non-null   object
#  9   durationSecs           6369 non-null   float64
#  10  tagCount               6369 non-null   int64
#  11  Publish_date           6369 non-null   datetime64[ns]
#  12  Publish_time           6369 non-null   object
#  13  pushblishDayName_code  6369 non-null   int64
#  14  year                   6369 non-null   int64
#  15  month                  6369 non-null   int64
#  16  caption_dummy          6369 non-null   uint8
# dtypes: datetime64[ns](1), float64(4), int64(4), object(7), uint8(1)
# memory usage: 802.5+ KB

# %%
# describe statistics of the revised dataset
data_preprocessed.describe()
# Out:
#           viewCount    likeCount  commentCount  durationSecs     tagCount  \
# count  6.369000e+03  6369.000000   6369.000000   6369.000000  6369.000000
# mean   3.611489e+05  2656.869210    159.645156   2823.147590    10.790234
# std    2.472335e+05  1562.857424    112.946575   2866.372177     2.532569
# min    1.394000e+04   286.000000      6.000000     87.000000     3.000000
# 25%    1.683410e+05  1428.000000     72.000000   1333.000000     9.000000
# 50%    3.015680e+05  2338.000000    129.000000   1917.000000    11.000000
# 75%    4.889020e+05  3563.000000    221.000000   2866.000000    13.000000
# max    1.193597e+06  8549.000000    502.000000  28823.000000    19.000000
#
#        pushblishDayName_code         year        month  caption_dummy
# count            6369.000000  6369.000000  6369.000000    6369.000000
# mean                2.986340  2018.213377     6.431779       0.024023
# std                 1.999521     2.247033     3.458989       0.153131
# min                 0.000000  2014.000000     1.000000       0.000000
# 25%                 1.000000  2016.000000     3.000000       0.000000
# 50%                 3.000000  2018.000000     6.000000       0.000000
# 75%                 5.000000  2020.000000     9.000000       0.000000
# max                 6.000000  2022.000000    12.000000       1.000000

# %%
data_preprocessed["viewCount"].mean()
# Out:
# 361148.8957450149

# %% [markdown]
# # Data Modelling
# ## Assessment of the relationships
# As the intention of the project is to examine whether the likes follow a linear relationship with the views, the correlations between variables should be examined.
#
# For likes, the most correlated variables are view count, followed by comments and to a later extent year. Therefore, there is a relationship between view count and likes.

# %%
# correlation of the variables
corrMatrix = data_preprocessed.corr()

# heatmap of correlation 
plt.figure(figsize = (15,10))
sns.heatmap(corrMatrix, annot=True, cmap = "mako")
plt.suptitle("Correlation between variables")
plt.show()

# %% [markdown]
# Creating a scatter plot of the two variables, likes and view count, presents the following.

# %%
# scatter plot of views and likes
sns.jointplot(x="viewCount", y ="likeCount",kind="hex", data = data_preprocessed, height = 8)
plt.suptitle("Relationship between likes and views", y = 1)
plt.show()

# %% [markdown]
# As the view count increase the variations between the two factors appear to increase. However, the scale between the two counts is significantly different and as such should be scaled. Further alternations to the data may also aid the model and its accuracy.

# %% [markdown]
# ## Feature engineering
# Although outliers were excluded in the previous section of the project, to establish OLS, it appears that the log of the variables is required. This transforms the relationship to the following:

# %%
sns.displot( x ="viewCount" , data = data_preprocessed, height = 8)
plt.title("Distribution of views")
plt.show()

# %%
sns.displot( x ="likeCount" , data = data_preprocessed, height = 8)
plt.title("Distribution of likes")
plt.show()

# %%
# transform likes and views via the log function
data_preprocessed["log_like"] = np.log(data_preprocessed["likeCount"])
data_preprocessed["log_view"] = np.log(data_preprocessed["viewCount"])

# %%
# revised relationship between likes and views
sns.jointplot(x="log_view", y ="log_like",kind="hex", data = data_preprocessed, height = 8)
plt.suptitle("Relationship between likes and views after log transformation")
plt.show()

# %% [markdown]
# These transformed views and like variables can now be used to model the relationship.

# %%
targets = data_preprocessed["log_like"]

log_view = data_preprocessed["log_view"] 
log_view_metrix = log_view.values.reshape(-1,1)
inputs = log_view_metrix

# %% [markdown]
# As the scale of the views to likes continue to differ greatly, the views will need to be scaled.

# %%
# scale views
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
scaler.fit(inputs)

inputs_scaled = scaler.transform(inputs)

# %% [markdown]
# Using the resulting variables, the data can be split into 80% of training and 20% for testing.

# %%
# import library for spliting data for train and testing a model. 
from sklearn.model_selection import train_test_split

# %%
# split variables to train and test 
x_train, x_test, y_train, y_test = train_test_split(inputs_scaled, targets, test_size=0.2, random_state= 360)

# %%
# import libaray for linear regression
from sklearn.linear_model import LinearRegression

# %%
# create linear regression

reg = LinearRegression()
reg.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
# predict likes
y_hat = reg.predict(x_train)

# %%
# plot predicted and actual likes (train values)
plt.figure(figsize = (15,10))
plt.scatter (y_train, y_hat)
plt.title("Accuracy of the like predictions - model training")
plt.show()

# %%
# distribution of residual
sns.displot(y_train-y_hat, kind="kde")
plt.show()

# %% [markdown]
# The resulting predicted variables appear to have some deviation from the actual values. Examining the regression score, the model has an accurate rate of 68.5%. This suggest that whilst the there is a relationship (log-log linear model) between the views and likes, it is not the only factor.  Examining worst predictions, at times it can predict over 120% of the actual value.

# %%
# accuracy score
reg.score(x_train, y_train)
# Out:
# 0.6854328618018846

# %%
# intercept of linear regression
reg.intercept_
# Out:
# 7.697692322824207

# %%
# change in % of likes for a 1% change in views 
reg.coef_
# Out:
# array([0.53063493])

# %%
# summary of the coefs 
reg_summary = pd.DataFrame(reg.coef_, columns =["weights"])
reg_summary["Features"]= "log_views"
reg_summary
# Out:
#     weights   Features
# 0  0.530635  log_views

# %%
y_hat_test = reg.predict(x_test)

# %%
from sklearn import metrics
np.sqrt(metrics.mean_absolute_error(y_test, y_hat_test))
# Out:
# 0.542954224885108

# %%
print( round(metrics.explained_variance_score(y_test, y_hat_test),3), "is the explained variance score (R^2)")
# Out:
# 0.664 is the explained variance score (R^2)

# %%
plt.scatter (y_test, y_hat_test, alpha= 0.2)
plt.show()

# %%
df_pf =pd.DataFrame (np.exp(y_hat_test), columns = ["Predict"])

# %%
y_test = y_test.reset_index(drop = True)
df_pf["Target"] =np.exp(y_test)

# %%
df_pf["Residual"] =df_pf["Target"] - df_pf["Predict"]

df_pf["Difference%"] = np.absolute(df_pf["Residual"]/df_pf["Target"])*100
df_pf
# Out:
#           Predict  Target     Residual  Difference%
# 0     4931.813658  5426.0   494.186342     9.107747
# 1     1694.655195  1756.0    61.344805     3.493440
# 2     3916.547017  4383.0   466.452983    10.642322
# 3     2897.641470  3252.0   354.358530    10.896634
# 4     4427.535149  3075.0 -1352.535149    43.984883
# ...           ...     ...          ...          ...
# 1269  1751.610472  1611.0  -140.610472     8.728148
# 1270  2585.736522  3506.0   920.263478    26.248245
# 1271  4024.232198  3788.0  -236.232198     6.236330
# 1272  1280.145106   858.0  -422.145106    49.201061
# 1273   719.909331  1691.0   971.090669    57.427006
#
# [1274 rows x 4 columns]

# %%
df_pf.describe()
# Out:
#            Predict       Target     Residual  Difference%
# count  1274.000000  1274.000000  1274.000000  1274.000000
# mean   2467.401435  2619.448980   152.047545    30.266447
# std    1199.651118  1514.981134  1011.062859    23.641220
# min     303.216658   297.000000 -2312.640177     0.004989
# 25%    1521.671645  1447.000000  -460.312916    12.588715
# 50%    2293.429361  2327.000000    38.355543    25.608862
# 75%    3214.468528  3503.250000   609.799023    43.078932
# max    6077.362370  8480.000000  4870.799851   122.424357

# %%
pd.options.display.max_rows = 100
df_pf.sort_values(by ="Difference%", ascending=False).head(50)
# Out:
#           Predict  Target     Residual  Difference%
# 733   3827.923190  1721.0 -2106.923190   122.424357
# 214   2281.274020  1046.0 -1235.274020   118.095031
# 547   2647.381638  1215.0 -1432.381638   117.891493
# 1014   976.224114   460.0  -516.224114   112.222633
# 999   1970.652112   946.0 -1024.652112   108.314177
# 713    979.582617   472.0  -507.582617   107.538690
# 360   2946.893429  1424.0 -1522.893429   106.944763
# 179   2092.375327  1013.0 -1079.375327   106.552352
# 979   1048.468099   509.0  -539.468099   105.985874
# 15    2024.044788   983.0 -1041.044788   105.904861
# 728   1114.782564   542.0  -572.782564   105.679440
# 419   1182.001248   575.0  -607.001248   105.565434
# 405   4065.420025  1992.0 -2073.420025   104.087351
# 771    938.621478   463.0  -475.621478   102.726021
# 141   2155.387297  1071.0 -1084.387297   101.249981
# 277   2143.176075  1075.0 -1068.176075    99.365216
# 1012   896.678272   450.0  -446.678272    99.261838
# 1024  2108.011539  1062.0 -1046.011539    98.494495
# 1039  1221.831178   617.0  -604.831178    98.027744
# 322   2317.529332  1172.0 -1145.529332    97.741411
# 993   1011.550712   513.0  -498.550712    97.183375
# 681   2146.155125  1089.0 -1057.155125    97.075769
# 114   2384.589509  1213.0 -1171.589509    96.586110
# 254   2225.250389  1134.0 -1091.250389    96.230193
# 1008  1221.469868   624.0  -597.469868    95.748376
# 617   2075.757340  1062.0 -1013.757340    95.457377
# 930   1061.977098   545.0  -516.977098    94.858183
# 754   2195.843046  1128.0 -1067.843046    94.666937
# 216   1188.130660   611.0  -577.130660    94.456737
# 1110  1994.516377  1026.0  -968.516377    94.397308
# 665   1243.841857   641.0  -602.841857    94.047092
# 1134  1771.624230   914.0  -857.624230    93.831973
# 614   2366.318125  1222.0 -1144.318125    93.643054
# 822    972.915325   506.0  -466.915325    92.275756
# 251   1521.650686   793.0  -728.650686    91.885332
# 910   2563.980592  1343.0 -1220.980592    90.914415
# 856   1747.564381   920.0  -827.564381    89.952650
# 1218   847.069892   449.0  -398.069892    88.656992
# 814   2618.165654  1390.0 -1228.165654    88.357241
# 282   2019.973254  1080.0  -939.973254    87.034561
# 800    888.218418   476.0  -412.218418    86.600508
# 185    974.023993   522.0  -452.023993    86.594635
# 441   1330.390745   713.0  -617.390745    86.590567
# 33    2523.559819  1356.0 -1167.559819    86.103232
# 795   4831.018344  2597.0 -2234.018344    86.023040
# 1144  1726.839646   936.0  -790.839646    84.491415
# 1132  2604.012632  1412.0 -1192.012632    84.420158
# 189   1520.044488   827.0  -693.044488    83.802236
# 695   2520.338745  1373.0 -1147.338745    83.564366
# 194   2084.208708  1138.0  -946.208708    83.146635

# %% [markdown]
# As the number of comments and to a lesser extent year of publication had a correlation with likes, it may be best to explore adding  these variables to the model. As comments has a similar distribution to likes and views, it will need to be transformed.

# %%
sns.displot(x= "commentCount", data = data_preprocessed)
plt.show()

# %%
sns.jointplot(x="commentCount", y ="likeCount",kind="hex", data = data_preprocessed)
plt.show()

# %%
sns.jointplot(x="commentCount", y ="year",kind="hex", data = data_preprocessed)
plt.show()

# %%
data_preprocessed["log_comment"] = np.log(data_preprocessed["commentCount"])

# %%
targets = data_preprocessed["log_like"]

inputs = data_preprocessed[["log_view", "log_comment", "year"]]

# %%
scaler.fit(inputs)

inputs_scaled = scaler.transform(inputs)

# %%
x_train, x_test, y_train, y_test = train_test_split(inputs_scaled, targets, test_size=0.2, random_state= 360)

reg = LinearRegression()
reg.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
reg = LinearRegression()
reg.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
y_hat = reg.predict(x_train)
plt.figure(figsize = (10,5))
plt.scatter (y_train, y_hat)
plt.show()

# %%
sns.displot(y_train-y_hat, kind="kde")
plt.show()

# %% [markdown]
# Under this model, the accuracy is as high as 90% and the R^2 score is just under 90%. Therefore reverting back to the hypothesis, it cannot be rejected with significance confidence when views are used as the sole variable. However when other variables are used, the null hypothesis can be rejected with approx. 90% confidence.

# %%
reg.score(x_train, y_train)
# Out:
# 0.9027150044738871

# %%
reg.intercept_
# Out:
# 7.700580816870733

# %%
cdf = pd.DataFrame(reg.coef_, inputs.columns, columns = ["Coef"])
cdf
# Out:
#                  Coef
# log_view     0.485561
# log_comment  0.176400
# year         0.305718

# %%
y_hat_test = reg.predict(x_test)

# %%
plt.scatter (y_test, y_hat_test, alpha= 0.2)
plt.show()

# %%
df_pf2 =pd.DataFrame (np.exp(y_hat_test), columns = ["Predict"])

# %%
y_test = y_test.reset_index(drop = True)
df_pf2["Target"] =np.exp(y_test)

# %%
df_pf2["Residual"] =df_pf["Target"] - df_pf["Predict"]

df_pf2["Difference%"] = np.absolute(df_pf["Residual"]/df_pf["Target"])*100
df_pf2.describe()
# Out:
#            Predict       Target     Residual  Difference%
# count  1274.000000  1274.000000  1274.000000  1274.000000
# mean   2590.147528  2619.448980   152.047545    30.266447
# std    1437.853205  1514.981134  1011.062859    23.641220
# min     253.201781   297.000000 -2312.640177     0.004989
# 25%    1466.430219  1447.000000  -460.312916    12.588715
# 50%    2361.064107  2327.000000    38.355543    25.608862
# 75%    3374.521519  3503.250000   609.799023    43.078932
# max    9256.845753  8480.000000  4870.799851   122.424357

# %%
sns.lmplot(x="Target", y="Predict", data=df_pf2,)
plt.show()

# %%
np.sqrt(metrics.mean_absolute_error(y_test, y_hat_test))
# Out:
# 0.40032687206351963

# %%
print( round(metrics.explained_variance_score(y_test, y_hat_test),3), "is the explained variance score (R^2)")
# Out:
# 0.896 is the explained variance score (R^2)

# %% [markdown]
# # Evaluating the model
# Although this model has been build and appears to be relatively robust with a score of 90% and a RMSE of 0.4, it should be acknowledged that with regards to the Ordinary Least Squares (OLS) assumptions may not be fully applicable.
#
# Working through the OLS assumptions, the following can be stated about the model:
#
#     Linearity - this assumption holds after a log transformations.
#
#     No Endogeneity of Regressors - as the accuracy is only 90%, there may be missing variables. There were other data within the dataset which were not included that may improve the model further. There is also a risk of variables inaccessible that may also impact the likes rating. For instance, whether a YouTuber asks for likes and subscriptions in videos may impact the number of likes a video receives.
#
#     Normality and Homoiconicity - the sample is relatively large and there is a intercept. Therefore normality assumption should apply.  As for homoscedastic, whilst the log transformation reduced the impact, there was still variations in the results. This may be the noise/randomness in the number of likes.
#
#     No Autocorrelation - As the data is cross sectional, this should not be an issue here.
#
#     No Multicollinearity - this is the most likely to be violated. Views and comments share a correlation. More views will lead to more comments, though no user is required to comment. Nonetheless, this is likely to contradict the no multicollinearity rule. The comment variable could be dropped but this may reduce the accuracy of the model.
#
#
# ## Conclusion
# It was extremely interesting to discover how consistent 2BRO has been over the past 12 years. It is clear that they have a passion for their job, uploading every day and the majority of the clips lasting approx. 30mins.
#
# As for the modelling, there is a relationship between the view count and the likes. However, it is not a straight forward relationship. Both the independent and dependent variables required log transformation before modelling. However when the model only includes the one variable (views), its ability was relatively low.
#
# Adding more variables, comments and year of publication, improved the accuracy. This however raised further issues as key assumptions of OLS were broken through the use of comments. Moreover even with the increased variables the accuracy was approx. 90%.
